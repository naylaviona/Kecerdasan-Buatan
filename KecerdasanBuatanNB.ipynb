# %% [markdown]
# <a href="https://colab.research.google.com/github/naylaviona/Kecerdasan-Buatan/blob/main/KecerdasanBuatanNB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
path = "/content/drive/MyDrive/diabetes.csv"
dataset = pd.read_csv(path)
print(dataset)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
X = dataset[['Glucose','BMI','Age']]
y = dataset['Outcome']
print(X)
# Out:
#      Glucose   BMI  Age
# 0        148  33.6   50
# 1         85  26.6   31
# 2        183  23.3   32
# 3         89  28.1   21
# 4        137  43.1   33
# ..       ...   ...  ...
# 763      101  32.9   63
# 764      122  36.8   27
# 765      121  26.2   30
# 766      126  30.1   47
# 767       93  30.4   23
#
# [768 rows x 3 columns]

# %%
print(y)
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
   X, y, test_size=0.2, random_state=0
)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[94 13]
#  [21 26]]

# %%
print("Train Accuracy:", model.score(X_train, y_train))
print("Test Accuracy:", model.score(X_test, y_test))
# Out:
# Train Accuracy: 0.7654723127035831
# Test Accuracy: 0.7792207792207793

# %%
X_train.groupby(y_train).mean()
# Out:
#             Glucose        BMI        Age
# Outcome
# 0        109.949109  30.404835  31.442748
# 1        140.361991  35.410860  37.420814

# %%
X_train.groupby(y_train).var()
# Out:
#              Glucose        BMI         Age
# Outcome
# 0         665.232097  60.468829  143.456535
# 1        1039.368367  50.668427  123.726656
